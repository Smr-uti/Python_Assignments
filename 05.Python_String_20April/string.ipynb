# %%
s = "welcome to india"
print(s[-1])
print(s[-5])
print(s[-16])
# Out:
# a
# i
# w

# %%
str1="Smruti"
str1[0:5]
# Out:
# 'Smrut'

# %%
str2="welcome to india"
str2[0:7:2]
# Out:
# 'wloe'

# %%
str3="Programming"
str3[::]
print(str3)
# Out:
# Programming

# %%
str4="welcome to india"
str4[11:16]
str4[11:]
# Out:
# 'india'

# %%
str5="Hello"
type(str5)
# Out:
# str

# %%
str6="Python"
str6[1:-1]
# Out:
# 'ytho'

# %%
str7="Python \n Programming"
print(str7)
# Out:
# Python
#  Programming
