# %% [markdown]
# ## String Method
# #### 1.What will be the output of the following? Also predict whether it returns True or False.

# %%
language = "Python"
print(language.upper())
print(language.lower())
# Out:
# PYTHON
# python

# %% [markdown]
# #### 2. Check whether the string below contains only alphabets. Write the code and state why the result is True or False.

# %%
course = "DataScience"
print(course.isalpha())
# Out:
# True

# %% [markdown]
# #### 3. Predict the output of each print statement and explain the difference.
#
# #####  isalpha()- Sgle character alphabet ahet ka he check krte
# ##### isdigit()- Sgle character digits ahet ka he check krte
# #####  isalnum()- Alphabet ani digit character ahet ka check krte

# %%
username="Admin99"
print(username.isalpha())
print(username.isdigit())
print(username.isalnum())
# Out:
# False
# False
# True

# %% [markdown]
# #### 4. What will be the output? Justify your answer for each line.
# pythonpin hi string ahe isdigit() he fkt digit ahet ka he check krte.
# pin2 decimal point ahe. isdigit() fkt digit ch except krte

# %%
pin = "4872"
print(pin.isdigit())
pin2 = "48.72"
print(pin2.isdigit())
# Out:
# True
# False

# %% [markdown]
# #### 5. Predict the output of both print statements and explain the behavior of islower().
# #### ANSWER:
# ##### islower() la sgle character lowercase mdhe pahijet tr TRUE
# ##### Isupper() la sgle character uppercase mdhe pahijet tr TRUE

# %%
word1 = "hello world"
word2= "Hello World"
print(word1.islower())
print(word2.isupper())
# Out:
# True
# False

# %% [markdown]
# ####  6. What will be printed? State when isupper() returns True vs False.

# %%
tag1="PYTHON"
tag2="PyTHON"

print(tag1.isupper())
print(tag2.isupper())
# Out:
# True
# False

# %% [markdown]
# #### 7. What is the output of the following? Also explain what startswith() checks.

# %%
email="contact@gmail.com"

print(email.startswith("contact"))

print(email.startswith("gmail"))
# Out:
# True
# False

# %% [markdown]
# #### 8. Predict the output. Then explain why the second print gives False.
# ### ANSWER:
# ##### second print gives false karan docx ne end hot ahe

# %%
filename="report_2024.pdf"

print(filename.endswith(".pdf"))
print(filename.endswith(".docx"))

# %% [markdown]
# #### 9.What will find() return in each case? Write the output and explain.
# ##### python che p he 18 index la yete mhnun 18
# ##### Python che P he sentence mdhe nahi mhnun -1
# ##### Java sentence mdhe nahi mhnun -1
# ##### je element sentence mdhe nahit tyala -1 yete

# %%
sentence="Hello, welcome to python programming"

print(sentence.find("python"))
print(sentence.find("Python"))
print(sentence.find("java"))
# Out:
# 18
# -1
# -1

# %% [markdown]
# #### 10. Use len(), min(), and max() on the string below and write what each one returns.

# %%
city="Mumbai"
print(len(city))
print(min(city))
print(max(city))
# Out:
# 6
# M
# u

# %% [markdown]
# #### 11. Given the string below, use startswith() and endswith() together to check if it looks like a valid Python filename.

# %%
fname="assignment1.py"
print(fname.startswith("assignment"))
print(fname.endswith(".py"))
# Out:
# True
# True

# %% [markdown]
# #### 12.Predict the output. What is the difference between isalpha() and isalnum()?

# %%
val1 = "Rupee100"
val2 = "Rupee"
print(val1.isalpha())
print(val1.isalnum())
print(val2.isalpha())
print(val2.isalnum())
# Out:
# False
# True
# True
# True

# %% [markdown]
# #### 13. What index does find() return for 'india' in the string below? Verify using indexing.

# %%
phrase = "welcome to india"
idx = phrase.find("india")
print(idx)
print(phrase[idx:idx+5])
# Out:
# 11
# india

# %% [markdown]
# #### 14.What will be the output? Explain the role of len() as a built-in function vs a method.

# %%
product = "Laptop"
print(len(product))
print(max(product))
print(min(product))
# Out:
# 6
# t
# L

# %% [markdown]
# #### 15.Write code to check all of the following for the string below and predict each output.

# %%
data = "HelloWorld"
print(data.isalpha())
print(data.islower())
print(data.isupper())
print(data.startswith("Hello"))
print(data.endswith("World"))
# Out:
# True
# False
# False
# True
# True
