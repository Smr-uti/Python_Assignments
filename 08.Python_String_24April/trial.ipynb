# %%
age=25
text ="Age is " + str(age)
print(text)
# Out:
# Age is 25

# %%
a = complex(5, 10)
print(str(a))
# Out:
# (5+10j)

# %%
text="Whoareyou?"
sentence=text.partition()
print(sentence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 text="Whoareyou?"
# ----> 2 sentence=text.partition()
#       3 print(sentence)
#
# TypeError: str.partition() takes exactly one argument (0 given)
