# %% [markdown]
# #### 1. What will be the output? Predict before running.

# %%
intro = "Hello, welcome to Python programming"
updated_intro = intro.replace("Python", "Java")
print(updated_intro)
# Out:
# Hello, welcome to Java programming

# %% [markdown]
# #### 2. What will be the output of both print statements? What does lstrip() remove?

# %%
raw_name= "  Amit Kumar  "
print(raw_name)
stripped_left =raw_name.lstrip() ##lsstrip() method removes left side whitespace 
print(stripped_left)
# Out:
#   Amit Kumar
# Amit Kumar

# %% [markdown]
# #### 3. Predict the output. What does rstrip() keep and what does it remove?

# %%
padded_city="   Pune   "
stripped_right= padded_city.rstrip() ## rstrip removes right side whitespace

print(stripped_right)
# Out:
#    Pune

# %% [markdown]
# #### 4.What will be the output? Explain the difference between strip() and lstrip().

# %%
user_input = "   Data Science   "
clean_input = user_input.strip() ## strip() remove bothh left and right side whitespace.
print(clean_input) ## lstrip() remove left side whitespace.
# Out:
# Data Science

# %% [markdown]
# #### 5.Predict the output. What data type does split() return?

# %%
address= "Mumbai Pune Delhi Chennai"
city_list = address.split() ## split() returns list datatype.
print(city_list)
# Out:
# ['Mumbai', 'Pune', 'Delhi', 'Chennai']

# %% [markdown]
# #### 6.What will be the output? How many parts does partition() always return?

# %%
bio="My name is Rajesh"
bio_parts = bio.partition("is") ## always return in 3 parts one is the part from where u want to partition and another two are from left side and right side of that partition word
print(bio_parts)
# Out:
# ('My name ', 'is', ' Rajesh')

# %% [markdown]
# #### 7. What will be the output of both print statements?

# %%
department = "COMPUTER SCIENCE"
dept_lower = department.lower()
print(dept_lower)

subject = "machine learning"
subject_upper = subject.upper()
print(subject_upper)
# Out:
# computer science
# MACHINE LEARNING

# %% [markdown]
# #### 8. Predict the output. What exactly does capitalize() do to the rest of the string?

# %%
college_name = "dr ambedkar institute of technology"
formatted_college = college_name.capitalize()
print(formatted_college)
# Out:
# Dr ambedkar institute of technology

# %% [markdown]
# #### 9.What will be the output? How is title() different from capitalize()?

# %%
book_title = "the art of python programming"
proper_title = book_title.title() ##title() converts the first character of every word to uppercase.
print(proper_title) ## capitalize converts the first character of the string to uppercase.
# Out:
# The Art Of Python Programming

# %% [markdown]
# #### 10. Predict the output. What does swapcase() do to each character?

# %%
mixed_text = "pYTHON iS fUN"
swapped = mixed_text.swapcase() ## swapcase() Uppercase characters become lowercase. Lowercase characters become uppercase.
print(swapped)
# Out:
# Python Is Fun

# %% [markdown]
# #### 11. What will be the output of all three print statements?

# %%
marks = 95
percentage = 87.5
comp_num = 3+2j

marks_str = str(marks) ## print statments are converted into string so Output is <class 'str'>
percentage_str = str(percentage)
comp_str = str(comp_num)
print(type(marks_str))
print(type(percentage_str))
print(type(comp_str))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# #### 12.What will be the output? What does chr() take as input?

# %%
letter1 = chr(66) ## chr() takes unicode value as a input
print(letter1)
letter2 = chr(98)
print(letter2)
# Out:
# B
# b

# %% [markdown]
# #### 13. What will be the output? What does ord() take as input?

# %%
code1 = ord("Z") ##ord() takes characters as a input 
print(code1)
code2 = ord("z")
print(code2)
# Out:
# 90
# 122

# %% [markdown]
# #### 14. Predict the output. What does join() use as the separator here?

# %%
skills = ["Python", "SQL", "Machine Learning", "Excel"]
skill_set = ", ".join(skills) ## join() used , as a separator here
print(skill_set)
# Out:
# Python, SQL, Machine Learning, Excel

# %% [markdown]
# #### 15.What will be the output of all three prints?

# %%
employee_data = "emp:Suresh:dept:HR"
updated_data = employee_data.replace("Suresh", "Ganesh")
print(updated_data)
split_data = employee_data.split(":")
print(split_data)
partition_data = employee_data.partition(":")
print(partition_data)
# Out:
# emp:Ganesh:dept:HR
# ['emp', 'Suresh', 'dept', 'HR']
# ('emp', ':', 'Suresh:dept:HR')
