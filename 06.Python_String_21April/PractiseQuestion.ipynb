# %% [markdown]
# #### 1. Explain why strings are immutable in Python.

# %% [markdown]
# :-- Strings are immutable, meaning once a string is created, its content cannot be changed, modified, or replaced.

# %% [markdown]
# #### 2. Write a program to access the first and last character of a string.

# %%
text="Program"
print(text[0])
print(text[6])
# Out:
# P
# m

# %% [markdown]
# #### 3. Write a program to extract a word from a sentence using slicing.

# %%
text="I am AgenticAI Engineer"
print(text[4:12])
# Out:
#  Agentic

# %% [markdown]
# #### 4. Write a program to join first name and last name using concatenation.

# %%
first_name="Smruti"
last_name="More"
full_name=first_name+last_name

print(full_name)
# Out:
# SmrutiMore

# %% [markdown]
# #### 5. Write a program to repeat a string 4 times using the repetition operator.

# %%
text1="India "
repeated_text1=text1*4

print(repeated_text1)
# Out:
# India India India India

# %% [markdown]
# #### 6. Write a program to check whether a given substring exists inside another string.

# %%
phrase="I am AgenticAI Engineer"
print("AgenticAI" in phrase)
# Out:
# True

# %% [markdown]
# #### 7. Write a program to check whether a word is not present in a sentence.

# %%
phrase="I am AgenticAI Engineer"
print("Python" not in phrase)
# Out:
# True

# %% [markdown]
# #### 8. Write a program to find the length of a string using `len()`.

# %%
text1="AgenticAi"
print(len(text1))
# Out:
# 9

# %% [markdown]
# #### 9. Write a program to find the minimum character in a string.

# %%
text1="AgenticAI"
print(min(text1))
# Out:
# A

# %% [markdown]
# #### 10. Write a program to find the maximum character in a string.

# %%
text1="AgenticAi"
print(max(text1))
# Out:
# t

# %% [markdown]
# 11. Write a program to print the ASCII value of a given character using `ord()`.

# %%
text1="Engineer"
print(ord("E"))

print(ord("n"))

print(ord("g"))

print(ord("i"))

print(ord("n"))

print(ord("e"))

print(ord("e"))

print(ord("r"))
# Out:
# 69
# 110
# 103
# 105
# 110
# 101
# 101
# 114

# %% [markdown]
# #### 12. Write a program to print the character from a given ASCII value using `chr()`.

# %%
character=chr(101)
print(character)
# Out:
# e

# %% [markdown]
# #### 13. Write a program to reverse a string using slicing.

# %%
text1="I am AgenticAIEngineer"
print(text1[::-1])
# Out:
# reenignEIAcitnegA ma I
