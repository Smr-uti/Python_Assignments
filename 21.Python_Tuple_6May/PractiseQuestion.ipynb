# %% [markdown]
# #### P1. Write the syntax to create a tuple. What brackets are used?

# %% [markdown]
# :-- To create a Tuple in python we use parantheses ().
# Syntax :- tup = (element1, element2, element3)

# %% [markdown]
# #### P2. Create a tuple called `colors` with three string values: "red", "green", "blue". Print it and its type.

# %%
colors = ("red", "green", "blue")
print(colors)
print(type(colors))
# Out:
# ('red', 'green', 'blue')
# <class 'tuple'>

# %% [markdown]
# #### P3. Create a homogeneous tuple called `marks` with values (85, 90, 78, 92, 88). Print it.

# %%
marks = (85, 90, 78, 92, 88)
print(marks)
# Out:
# (85, 90, 78, 92, 88)

# %% [markdown]
# #### P4. Create a heterogeneous tuple called `student` with: name (string), roll number (int), percentage (float), and passed (bool). Print it.

# %%
student = ("Rahul", 101, 65, True)
print(student)
# Out:
# ('Rahul', 101, 65, True)

# %% [markdown]
# #### P5. What is the output of the following code? tup = ("apple", "mango", "banana") print(type(tup))

# %%
tup = ("apple", "mango", "banana")
print(type(tup))
# Out:
# <class 'tuple'>

# %% [markdown]
# #### P6. Create the tuple (10, 20, 30, 40, 50). Print the element at index 1. What is the output?

# %%
tuple1 = (10, 20, 30, 40, 50)
print(tuple1[1])
# Out:
# 20

# %% [markdown]
# #### P7. Given tup1 = ("Akshay", 100, 65.6, True): Print the element at index 0 and index 2.

# %%
tup1 = ("Akshay", 100, 65.6, True)
print(tup1[0])
print(tup1[2])
# Out:
# Akshay
# 65.6

# %% [markdown]
# #### P8. True or False: "The order of elements in a tuple can change after creation." Explain your answer

# %% [markdown]
# :-- Tuples are immutable means once created their cannot be changed.
# We cannot add, remove or change element after a tuple is create.

# %% [markdown]
# ##### P9. Create a tuple (50, 30, 10, 40, 20) and print the whole tuple. Notice that the order is preserved exactly as you entered it.

# %%
tup2 = (50, 30, 10, 40,20)
print(tup2)
# Out:
# (50, 30, 10, 40, 20)

# %% [markdown]
# #### P10. Create tup1 = (10, 20, 30). Try to change the first element to 99 using tup1[0] = 99. What error do you get? Write the error name.

# %%
tup1 = (10, 20, 30)
tup1[0] = 99 #TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 tup1 = (10, 20, 30)
# ----> 2 tup1[0] = 99 #TypeError: 'tuple' object does not support item assignment
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### P11. Try calling tup1.append(40) on a tuple. What error do you get?

# %%
tup1 = (10, 20, 30)
tup1.append(40) #AttributeError: 'tuple' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 tup1 = (10, 20, 30)
# ----> 2 tup1.append(40)
#
# AttributeError: 'tuple' object has no attribute 'append'
