# %%
a=5
b=2
c=5%2
print(c)
# Out:
# 1

# %%
x=5
y=2
z=c**2
print(z)
# Out:
# 1

# %%
print(2 + 3 * 4)
# Out:
# 14

# %%
print((2 + 3) * 4)
# Out:
# 20

# %%
print(2 + 3 ** 2)
# Out:
# 11

# %%
int(3.8)
# Out:
# 3

# %%
float("3.14")
# Out:
# 3.14

# %%
bool(0)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool("Hello")
# Out:
# True

# %%
complex(True)
# Out:
# (1+0j)

# %%
1a=10
# Out:
#   Cell In[12], line 1
#     1a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
false=10

# %%
a=10
a=3.14

print(type(a))
# Out:
# <class 'float'>

# %%
int(3.9)
# Out:
# 3
